# %% [markdown]
# <a href="https://colab.research.google.com/github/Rubinisuresh/Course_9/blob/main/Week_5_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("/content/m5_survey_data_technologies_normalised.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74590 entries, 0 to 74589
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              74589 non-null  float64
#  1   LanguageWorkedWith      59792 non-null  object
#  2   LanguageDesireNextYear  55764 non-null  object
#  3   DatabaseWorkedWith      31375 non-null  object
#  4   DatabaseDesireNextYear  29575 non-null  object
#  5   PlatformWorkedWith      39208 non-null  object
#  6   PlatformDesireNextYear  44314 non-null  object
#  7   WebFrameWorkedWith      24803 non-null  object
#  8   WebFrameDesireNextYear  24567 non-null  object
#  9   DevEnviron              33306 non-null  object
#  10  OpSys                   0 non-null      float64
#  11  Containers              0 non-null      float64
#  12  BlockchainOrg           0 non-null      float64
#  13  BlockchainIs            0 non-null      float64
# ...

# %%
df_lang = df.groupby('LanguageWorkedWith',axis=0).count()
df_lang.head(10)
# Out:
#                        Respondent  LanguageDesireNextYear  DatabaseWorkedWith  \
# LanguageWorkedWith
# Assembly                      437                     432                 417
# Bash/Shell/PowerShell        4642                    4598                4435
# C                            1578                    1537                1318
# C#                           4288                    4103                3568
# C++                          1946                    1850                1435
# Clojure                       164                     150                 135
# Dart                          237                     222                 197
# Elixir                        187                     180                 154
# Erlang                         98                      86                  73
# F#                            158                     146                  96
#
#                        DatabaseDesireNextYear  PlatformWorkedWith  \
# LanguageWorkedWith
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# LanguageWorkedWith
# JavaScript               8687
# HTML/CSS                 7830
# SQL                      7106
# Bash/Shell/PowerShell    4642
# Python                   4542
# Java                     4506
# C#                       4288
# TypeScript               3232
# PHP                      2913
# C++                      1946
# Name: Respondent, dtype: int64

# %%
df_lang = df.groupby('DatabaseWorkedWith',axis=0).count()
df_lang.head(10)
# Out:
#                       Respondent  LanguageWorkedWith  LanguageDesireNextYear  \
# DatabaseWorkedWith
# Cassandra                    397                 397                     392
# Couchbase                    250                 250                     247
# DynamoDB                     831                 829                     814
# Elasticsearch               1954                1936                    1909
# Firebase                    1314                1309                    1282
# MariaDB                     1709                1700                    1655
# Microsoft SQL Server        4110                4061                    3913
# MongoDB                     3016                2953                    2837
# MySQL                       5469                5313                    4947
# Oracle                      1744                1659                    1509
#
#                       DatabaseDesireNextYear  PlatformWorkedWith  \
# DatabaseWorkedWith
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# DatabaseWorkedWith
# MySQL                   5469
# Microsoft SQL Server    4110
# PostgreSQL              4097
# SQLite                  3248
# MongoDB                 3016
# Redis                   2508
# Elasticsearch           1954
# Oracle                  1744
# MariaDB                 1709
# Firebase                1314
# Name: Respondent, dtype: int64

# %%
df_lang = df.groupby('WebFrameWorkedWith',axis=0).count()
df_lang.head(10)
# Out:
#                     Respondent  LanguageWorkedWith  LanguageDesireNextYear  \
# WebFrameWorkedWith
# ASP.NET                   3042                3026                    2965
# Angular/Angular.js        3327                3324                    3282
# Django                    1176                1174                    1147
# Drupal                     291                 289                     279
# Express                   2028                2019                    1936
# Flask                     1186                1168                    1118
# Laravel                    939                 920                     853
# Other(s):                  814                 774                     720
# React.js                  3302                3159                    2910
# Ruby on Rails              856                 826                     760
#
#                     DatabaseWorkedWith  DatabaseDesireNextYear  \
# WebFrameWorkedWith
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# WebFrameWorkedWith
# jQuery                4629
# Angular/Angular.js    3327
# React.js              3302
# ASP.NET               3042
# Express               2028
# Spring                1728
# Vue.js                1485
# Flask                 1186
# Django                1176
# Laravel                939
# Name: Respondent, dtype: int64

# %%
df_lang = df.groupby('LanguageDesireNextYear',axis=0).count()
df_lang.head(10)
# Out:
#                         Respondent  LanguageWorkedWith  DatabaseWorkedWith  \
# LanguageDesireNextYear
# Assembly                       336                 335                 320
# Bash/Shell/PowerShell         3097                3096                2943
# C                             1028                1025                 847
# C#                            3591                3557                3045
# C++                           1633                1619                1214
# Clojure                        413                 408                 355
# Dart                           610                 606                 519
# Elixir                         620                 609                 509
# Erlang                         310                 292                 223
# F#                             621                 586                 367
#
#                         DatabaseDesireNextYear  PlatformWorkedWith  \
# LanguageDesireNextYear
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# LanguageDesireNextYear
# JavaScript               6630
# HTML/CSS                 5328
# Python                   5239
# SQL                      5012
# TypeScript               4088
# C#                       3591
# Bash/Shell/PowerShell    3097
# Java                     2953
# Go                       2759
# Kotlin                   1890
# Name: Respondent, dtype: int64

# %%
df_lang = df.groupby('DatabaseDesireNextYear',axis=0).count()
df_lang.head(10)
# Out:
#                         Respondent  LanguageWorkedWith  \
# DatabaseDesireNextYear
# Cassandra                     1003                1001
# Couchbase                      390                 388
# DynamoDB                      1044                1031
# Elasticsearch                 2856                2813
# Firebase                      1650                1612
# MariaDB                       1385                1350
# Microsoft SQL Server          2706                2626
# MongoDB                       3649                3510
# MySQL                         3281                3068
# Oracle                         870                 766
#
#                         LanguageDesireNextYear  DatabaseWorkedWith  \
# DatabaseDesireNextYear
# Cassandra                                  989                 987
# Couchbase                                  382                 370
# DynamoDB                                  1026                1000
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# DatabaseDesireNextYear
# PostgreSQL              4328
# MongoDB                 3649
# Redis                   3331
# MySQL                   3281
# Elasticsearch           2856
# Microsoft SQL Server    2706
# SQLite                  2437
# Firebase                1650
# MariaDB                 1385
# DynamoDB                1044
# Name: Respondent, dtype: int64

# %%
df_lang = df.groupby('WebFrameDesireNextYear',axis=0).count()
df_lang.head(10)
# Out:
#                         Respondent  LanguageWorkedWith  \
# WebFrameDesireNextYear
# ASP.NET                       2382                2360
# Angular/Angular.js            3059                3055
# Django                        1504                1496
# Drupal                         168                 166
# Express                       1957                1937
# Flask                         1240                1205
# Laravel                        863                 825
# Other(s):                      762                 715
# React.js                      4714                4476
# Ruby on Rails                  970                 879
#
#                         LanguageDesireNextYear  DatabaseWorkedWith  \
# WebFrameDesireNextYear
# ASP.NET                                   2350                2048
# Angular/Angular.js                        3024                2973
# Django                                    1475                1358
# ...

# %%
df_lang.sort_values('Respondent',ascending=False,inplace=True)
df_lang['Respondent'].head(10)
# Out:
# WebFrameDesireNextYear
# React.js              4714
# Vue.js                3143
# Angular/Angular.js    3059
# ASP.NET               2382
# jQuery                2241
# Express               1957
# Spring                1564
# Django                1504
# Flask                 1240
# Ruby on Rails          970
# Name: Respondent, dtype: int64

# %%
df = pd.read_csv("/content/m5_survey_data_demographics.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Respondent      11398 non-null  int64
#  1   MainBranch      11398 non-null  object
#  2   Hobbyist        11398 non-null  object
#  3   OpenSourcer     11398 non-null  object
#  4   OpenSource      11317 non-null  object
#  5   Employment      11398 non-null  object
#  6   Country         11398 non-null  object
#  7   Student         11347 non-null  object
#  8   EdLevel         11286 non-null  object
#  9   UndergradMajor  10661 non-null  object
#  10  EduOther        11234 non-null  object
#  11  OrgSize         11302 non-null  object
#  12  DevType         11333 non-null  object
#  13  YearsCode       11389 non-null  object
#  14  Age1stCode      11385 non-null  object
#  15  YearsCodePro    11382 non-null  object
#  16  CareerSat       11398 non-null  object
# ...

# %%
df_lang = df.groupby('WebFrameDesireNextYear',axis=0).count()
df_lang.head(10)

# %%
df = pd.read_csv("/content/marketing_sample_for_naukri_com-jobs__20190701_20190830__30k_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Uniq Id                  30000 non-null  object
#  1   Crawl Timestamp          30000 non-null  object
#  2   Job Title                29425 non-null  object
#  3   Job Salary               29950 non-null  object
#  4   Job Experience Required  29427 non-null  object
#  5   Key Skills               28729 non-null  object
#  6   Role Category            27695 non-null  object
#  7   Location                 29423 non-null  object
#  8   Functional Area          29427 non-null  object
#  9   Industry                 29427 non-null  object
#  10  Role                     29099 non-null  object
# dtypes: object(11)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#                                  Uniq Id            Crawl Timestamp  \
# count                              30000                      30000
# unique                             30000                      28865
# top     9be62c49a0b7ebe982a4af1edaa7bc5f  2019-08-04 02:01:21 +0000
# freq                                   1                          5
#
#                Job Title                    Job Salary  \
# count              29425                         29950
# unique             23884                          1258
# top      Sales Executive   Not Disclosed by Recruiter
# freq                 120                         19731
#
#        Job Experience Required  \
# count                    29427
# unique                     256
# top                  2 - 5 yrs
# freq                      2002
#
#                                             Key Skills         Role Category  \
# count                                            28729                 27695
# ...

# %%
df['Role Category']
# Out:
# 0                                       Advertising
# 1                                      Retail Sales
# 2                                               R&D
# 3        Admin/Maintenance/Security/Datawarehousing
# 4                              Programming & Design
#                             ...
# 29995                          Programming & Design
# 29996                                    Operations
# 29997                              University Level
# 29998                          Programming & Design
# 29999                      Online/Digital Marketing
# Name: Role Category, Length: 30000, dtype: object

# %%
df['Job Title'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Name: Job Title, Length: 30000, dtype: bool

# %%
df['Job Title'].dropna()
# Out:
# 0                                    Digital Media Planner
# 1                                 Online Bidding Executive
# 2         Trainee Research/ Research Executive- Hi- Tec...
# 3                                        Technical Support
# 4                        Software Test Engineer -hyderabad
#                                ...
# 29995                                MTS-Software-Engineer
# 29996                          Client Relationship Manager
# 29997                                     Assoc. Prof.- CS
# 29998           Application/Cyber Security Specialist-Pune
# 29999                           Press Release Writer - SEO
# Name: Job Title, Length: 29425, dtype: object

# %%
df['Job Title'].isnull().sum()
# Out:
# 575
